# %% [markdown]
# ## LINEAR REGRESSION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("car-sales-extended.csv")
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %% [markdown]
# #### Relation between odometer, doors and the price of the car

# %%
lis = ["Doors","Odometer (KM)"]
x = df[lis]
y=  df["Price"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(x_test)
predictions[0:10]
# Out:
# array([ 7801.52862037, 11214.5213321 , 17279.52893473, 16786.22090868,
#        23796.41072305, 11727.33839678, 10596.05801174, 12819.0334422 ,
#         8063.00694394, 15916.62467531])

# %%
y_test[0:10]
# Out:
# 521    13707
# 737    12650
# 740    19500
# 660    26880
# 411    41294
# 678     3751
# 626    13272
# 513    13213
# 859     9450
# 136    10582
# Name: Price, dtype: int64
